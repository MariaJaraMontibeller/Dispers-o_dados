# %% [markdown]
# Diagrama de dispersão dos dados, ASO é y e LARGURA é x

# %%
df = pd.DataFrame({'ASO':[1.02, 1.21, 0.88, 0.98, 1.52, 1.83, 1.50, 1.80, 1.74, 1.63, 2.00, 2.80, 2.48, 2.47, 3.05, 3.18, 3.76, 3.68, 3.82, 3.21, 4.27, 3.12, 3.99, 3.75, 4.10, 4.18, 3.77, 4.34, 4.21, 4.92],
                   'LARGURA':[0.40, 0.42, 0.48, 0.51, 0.57, 0.60, 0.70, 0.75, 0.75, 0.78, 0.84, 0.95, 0.99, 1.03, 1.12, 1.15, 1.20, 1.25, 1.25, 1.28, 1.30, 1.34, 1.37, 1.40, 1.43, 1.46, 1.49, 1.55, 1.58, 1.60],
                  })
df
# Out:
#      ASO  LARGURA
# 0   1.02     0.40
# 1   1.21     0.42
# 2   0.88     0.48
# 3   0.98     0.51
# 4   1.52     0.57
# 5   1.83     0.60
# 6   1.50     0.70
# 7   1.80     0.75
# 8   1.74     0.75
# 9   1.63     0.78
# 10  2.00     0.84
# 11  2.80     0.95
# 12  2.48     0.99
# 13  2.47     1.03
# 14  3.05     1.12
# 15  3.18     1.15
# 16  3.76     1.20
# 17  3.68     1.25
# 18  3.82     1.25
# 19  3.21     1.28
# 20  4.27     1.30
# 21  3.12     1.34
# 22  3.99     1.37
# 23  3.75     1.40
# 24  4.10     1.43
# 25  4.18     1.46
# 26  3.77     1.49
# 27  4.34     1.55
# 28  4.21     1.58
# 29  4.92     1.60

# %% [markdown]
# Importação de biblioteca

# %%
import seaborn as sns
import pandas as pd

# %%
sns.relplot(x="LARGURA", y="ASO", data=df);
